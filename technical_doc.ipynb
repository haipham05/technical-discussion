# %% [markdown]
# <a href="https://colab.research.google.com/github/haipham05/technical-discussion/blob/main/technical_doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  print('Hello World')

hello()
# Out:
# Hello World
